# %% [markdown]
# # Time Series Analysis with State Space Models
#
# This notebook demonstrates the modernized time series analysis capabilities including:
# - Synthetic data generation
# - State space models
# - ARIMA forecasting
# - Prophet modeling
# - Anomaly detection
# - Interactive visualizations
